# %%
import requests_random_user_agent
import requests
import pandas as pd 
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urlunparse
import re
import csv
import os

# %%
import requests
from bs4 import BeautifulSoup
import re

class EDGARDataFetcher:
    def __init__(self, cik_file_path, filing_type):
        self.cik_file_path = cik_file_path
        self.filing_type = filing_type
        self.cik_data = {}
        self.EDGAR_search_results = {}
        self.filing_data = {}
        self.base_url = r"https://www.sec.gov"

    def read_cik_data(self):
        with open(self.cik_file_path, 'r') as file:
            lines = file.readlines()
            
        for line in lines:
            line = line.strip()
            parts = line.split()

            if len(parts) == 2:
                word = parts[0]
                cik = parts[1]
                self.cik_data[word] = cik

    def fetch_filings(self):
        endpoint = r"https://www.sec.gov/cgi-bin/browse-edgar"
        
        for company, cik in self.cik_data.items():
            param_dict = {'action':'getcompany',
                          'CIK': cik,
                          'type': self.filing_type,
                          'owner':'exclude',
                          'output':'',
                          'count':'100'}

            response = requests.get(url=endpoint, params=param_dict)
            if response.status_code == 200:
                self.EDGAR_search_results[company] = response
            else:
                print('Request Failed')

    def get_filing_data(self):
        for company, url in self.EDGAR_search_results.items():
            soup = BeautifulSoup(url.content, 'html.parser')
            doc_table = soup.find_all('table', class_='tableFile2')
            master_list = []
            
            for row in doc_table[0].find_all('tr'):
                cols = row.find_all('td')
                
                if len(cols) != 0:
                    filing_type = cols[0].text.strip()
                    filing_date = cols[3].text.strip()
                    filing_numb = cols[4].text.strip()
                    filing_doc_href = cols[1].find('a', {'href':True, 'id':'documentsbutton'})
                    filing_int_href = cols[1].find('a', {'href':True, 'id':'interactiveDataBtn'})
                    filing_num_href = cols[4].find('a')

                    if filing_doc_href != None:
                        filing_doc_link = self.base_url + filing_doc_href['href'] 
                    else:
                        filing_doc_link = 'no link'

                    if filing_int_href != None:
                        filing_int_link = self.base_url + filing_int_href['href'] 
                    else:
                        filing_int_link = 'no link'

                    if filing_num_href != None:
                        filing_num_link = self.base_url + filing_num_href['href'] 
                    else:
                        filing_num_link = 'no link'

                    file_dict = {}
                    file_dict['file_type'] = filing_type
                    file_dict['file_number'] = filing_numb
                    file_dict['file_date'] = filing_date
                    file_dict['links'] = {}
                    file_dict['links']['documents'] = filing_doc_link

                    document_response = requests.get(filing_doc_link)
                    document_soup = BeautifulSoup(document_response.content, 'html.parser')
                    document_links = document_soup.find_all('a', {'href': lambda href: href.endswith('.txt')})
                    document = [document['href'] for document in document_links]
                    full_txt_url = "https://www.sec.gov" + document[0]
                    pattern = r"/\d{12,20}/"
                    modified_url = re.sub(pattern, "/",full_txt_url)
                    document_url = modified_url.replace('-','').replace('.txt', '/index.json')

                    try:
                        content = requests.get(document_url).json()
                        for file in content['directory']['item']:
                            if file['name'] == 'FilingSummary.xml':
                                xml_summary = self.base_url + content['directory']['name']  + "/" + file['name']
                                file_dict['links']['documents_xml'] = xml_summary
                    except requests.exceptions.RequestException as e:
                        print("Error occurred for:", document_url)
                        continue

                    file_dict['links']['interactive_data'] = filing_int_link
                    file_dict['links']['filing_number'] = filing_num_link
                    master_list.append(file_dict)

                self.filing_data[f"filing_{company}"] = master_list

if __name__ == "__main__":
    cik_file_path = "cik/liste_cik.txt"
    filing_type = "10-q"
    
    data_fetcher = EDGARDataFetcher(cik_file_path, filing_type)
    data_fetcher.read_cik_data()
    data_fetcher.fetch_filings()
    data_fetcher.get_filing_data()
    
    filing_data = data_fetcher.filing_data
    filing_data
# Out:
# Error occurred for: https://www.sec.gov/Archives/edgar/data/320193/a2038036z10q/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/320193/a10q/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/d10qa/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/d10qa/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/d10q/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/d10q/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/d10q/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/0001032210010002730001/index.json
# Error occurred for: https://www.sec.gov/Archives/edgar/data/789019/0001032210005000380001/index.json

# %%
filing_data
# Out:
# {'filing_aapl': [{'file_type': '10-Q',
#    'file_number': '001-36743231141522',
#    'file_date': '2023-08-04',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/0000320193-23-000077-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000077/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-23-000077&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674323890444',
#    'file_date': '2023-05-05',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/0000320193-23-000064-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000064/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-23-000064&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674323582662',
#    'file_date': '2023-02-03',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/0000320193-23-000006-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019323000006/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-23-000006&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-36743221116600',
#    'file_date': '2022-07-29',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/0000320193-22-000070-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000070/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-22-000070&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674322868650',
#    'file_date': '2022-04-29',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/0000320193-22-000059-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000059/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-22-000059&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674322564628',
#    'file_date': '2022-01-28',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/0000320193-22-000007-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000007/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-22-000007&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-36743211119137',
#    'file_date': '2021-07-28',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000065/0000320193-21-000065-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000065/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-21-000065&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674321866148',
#    'file_date': '2021-04-29',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000056/0000320193-21-000056-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000056/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-21-000056&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674321561251',
#    'file_date': '2021-01-28',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/0000320193-21-000010-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-21-000010&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-36743201062122',
#    'file_date': '2020-07-31',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000062/0000320193-20-000062-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000062/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-20-000062&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674320837377',
#    'file_date': '2020-05-01',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000052/0000320193-20-000052-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000052/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-20-000052&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674320555794',
#    'file_date': '2020-01-29',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000010/0000320193-20-000010-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000010/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-20-000010&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674319989192',
#    'file_date': '2019-07-31',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000076/0000320193-19-000076-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000076/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-19-000076&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674319788072',
#    'file_date': '2019-05-01',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000066/0000320193-19-000066-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000066/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-19-000066&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674319552275',
#    'file_date': '2019-01-30',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000010/0000320193-19-000010-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000010/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-19-000010&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674318985212',
#    'file_date': '2018-08-01',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000100/0000320193-18-000100-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000100/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-18-000100&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674318800115',
#    'file_date': '2018-05-02',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000070/0000320193-18-000070-index.htm',
#     'documents_xml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000070/FilingSummary.xml',
#     'interactive_data': 'https://www.sec.gov/cgi-bin/viewer?action=view&cik=320193&accession_number=0000320193-18-000070&xbrl_type=v',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=001-36743&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '001-3674318568703',
#    'file_date': '2018-02-02',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/320193/

#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000119312504076795/0001193125-04-076795-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427804573337',
#    'file_date': '2004-02-06',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000119312504016249/0001193125-04-016249-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427803999290',
#    'file_date': '2003-11-13',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000119312503080353/0001193125-03-080353-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427803693414',
#    'file_date': '2003-05-12',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000103221003000809/0001032210-03-000809-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427803535264',
#    'file_date': '2003-01-31',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000103221003000121/0001032210-03-000121-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427802825308',
#    'file_date': '2002-11-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000103221002001614/0001032210-02-001614-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427802625544',
#    'file_date': '2002-04-30',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/000103221002000709/0001032210-02-000709-index.htm',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-14278629580',
#    'file_date': '2000-05-12',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-00-001019-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-14278534418',
#    'file_date': '2000-02-11',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-00-000218-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427899741829',
#    'file_date': '1999-11-05',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-99-001526-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427899624316',
#    'file_date': '1999-05-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-99-000791-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427899537709',
#    'file_date': '1999-02-12',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-99-000191-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427898745910',
#    'file_date': '1998-11-12',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-98-001218-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q/A',
#    'file_number': '000-1427898641825',
#    'file_date': '1998-06-03',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-98-000581-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427898624938',
#    'file_date': '1998-05-15',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-98-000519-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427898542874',
#    'file_date': '1998-02-17',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0001032210-98-000171-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427897703011',
#    'file_date': '1997-10-29',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000898430-97-004575-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427897608312',
#    'file_date': '1997-05-15',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-97-000879-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427897534239',
#    'file_date': '1997-02-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-97-000207-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427896666210',
#    'file_date': '1996-11-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-96-001463-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427896566700',
#    'file_date': '1996-05-15',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-96-000492-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427896517045',
#    'file_date': '1996-02-13',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-96-000086-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427895592590',
#    'file_date': '1995-11-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-95-000534-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427895537989',
#    'file_date': '1995-05-12',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-95-000161-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427895510862',
#    'file_date': '1995-02-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-95-000027-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q/A',
#    'file_number': '000-1427894560457',
#    'file_date': '1994-11-16',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-94-000200-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427894559935',
#    'file_date': '1994-11-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-94-000198-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427894525884',
#    'file_date': '1994-05-03',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000891020-94-000070-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}},
#   {'file_type': '10-Q',
#    'file_number': '000-1427894507831',
#    'file_date': '1994-02-14',
#    'links': {'documents': 'https://www.sec.gov/Archives/edgar/data/789019/0000950109-94-000252-index.html',
#     'interactive_data': 'no link',
#     'filing_number': 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&filenum=000-14278&owner=exclude&count=100'}}]}

# %%
# Create "filing_type" file
folder_name = "filing_type"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

for key in filing_data.keys():
    data = globals()[key]

    # Spécifier le nom du fichier CSV
    csv_file = os.path.join(folder_name, f'{key}.csv')

    # Créer ou ouvrir le fichier CSV en mode écriture
    with open(csv_file, mode='w', newline='') as file:
        # Définir les noms de champ pour le fichier CSV
        fieldnames = ['file_type', 'file_number', 'file_date', 'documents', 'documents_xml', 'interactive_data', 'filing_number']

        # Créer le rédacteur CSV et écrire la ligne d'en-tête
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()

        # Écrire chaque ligne dans la liste de données dans le fichier CSV
        for row in data:
            # Extraire le dictionnaire de liens de la ligne
            links = row.pop('links')

            # Mettre à jour la ligne avec les données des liens
            row.update(links)

            # Écrire la ligne dans le fichier CSV
            writer.writerow(row)

    print(f'Data has been saved to {csv_file}')
